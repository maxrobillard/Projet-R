# %%
import numpy as np
import pandas as pd

# %%
youth = pd.read_csv("C:/Users/Utilisateur/Desktop/cours/Python_pour_la_data/projet/youth_alcohol/youth_good.csv")
tolerance = pd.read_csv("C:/Users/Utilisateur/Desktop/cours/Python_pour_la_data/projet/youth_alcohol/tolerance_good.csv")

# %%
youth.head()
# Out:
#    Unnamed: 0      Country  Year  \
# 0           1  Afghanistan  2016
# 1           2      Albania  2016
# 2           3      Algeria  2016
# 3           4      Andorra  2016
# 4           5       Angola  2016
#
#   15-19 years old, current drinkers both sexes (%)  \
# 0                                    0.3 [0.3-0.4]
# 1                                 37.7 [34.8-40.5]
# 2                                    1.5 [1.3-1.8]
# 3                                         64.2 [-]
# 4                                 33.5 [29.7-37.2]
#
#   15-19 years old, current males drinkers (%)  \
# 0                               0.5 [0.4-0.7]
# 1                              50.5 [46-54.9]
# 2                               2.3 [1.9-2.8]
# 3                                    76.6 [-]
# 4                              46 [39.8-52.3]
#
#   15-19 years old, current females drinkers (%)
# 0                                 0.1 [0.1-0.2]
# 1                              24.2 [21.1-27.6]
# ...

# %%
tolerance.head()
# Out:
#    Unnamed: 0      Country  Year  \
# 0           1  Afghanistan  2016
# 1           2      Albania  2016
# 2           3      Algeria  2016
# 3           4      Andorra  2016
# 4           5       Angola  2016
#
#    Legal blood alcohol concentration (BAC) limits for young/novice drivers
# 0                                               0.00
# 1                                               0.01
# 2                                               0.02
# 3                                               0.05
# 4                                               0.06

# %%
youth = youth.drop(['Unnamed: 0'] , axis = 'columns')

# %%
tolerance = tolerance.drop(['Unnamed: 0'] , axis = 'columns')

# %%
tolerance.head()
# Out:
#        Country  Year  \
# 0  Afghanistan  2016
# 1      Albania  2016
# 2      Algeria  2016
# 3      Andorra  2016
# 4       Angola  2016
#
#    Legal blood alcohol concentration (BAC) limits for young/novice drivers
# 0                                               0.00
# 1                                               0.01
# 2                                               0.02
# 3                                               0.05
# 4                                               0.06

# %%
youth.to_csv('youth_fin.csv' , index = False)
tolerance.to_csv('tolerance_fin.csv' , index = False)

# %%
youth_bis = pd.read_csv("C:/Users/Utilisateur/Desktop/cours/Python_pour_la_data/projet/youth_alcohol/youth_fin.csv")

# %%
youth_bis.head()
# Out:
#        Country  Year 15-19 years old, current drinkers both sexes (%)  \
# 0  Afghanistan  2016                                    0.3 [0.3-0.4]
# 1      Albania  2016                                 37.7 [34.8-40.5]
# 2      Algeria  2016                                    1.5 [1.3-1.8]
# 3      Andorra  2016                                         64.2 [-]
# 4       Angola  2016                                 33.5 [29.7-37.2]
#
#   15-19 years old, current males drinkers (%)  \
# 0                               0.5 [0.4-0.7]
# 1                              50.5 [46-54.9]
# 2                               2.3 [1.9-2.8]
# 3                                    76.6 [-]
# 4                              46 [39.8-52.3]
#
#   15-19 years old, current females drinkers (%)
# 0                                 0.1 [0.1-0.2]
# 1                              24.2 [21.1-27.6]
# 2                                 0.7 [0.6-0.9]
# 3                                      50.7 [-]
# ...
